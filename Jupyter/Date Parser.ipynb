# %%
data <- read.csv(file = '../data/store.csv', sep = ';')

# %%
data[101:107,]
date = data[,1]
# Out:
#     date       all  female male young adult weather maxtemp RH maxwind
# 101 2013-07-18 3767 1769   1813 1725  2042  Sunny   23      80 35
# 102 2013-07-19 3718 1725   1814 1687  2031  Sunny   22      73 39
# 103 2013-07-20 4426 2087   2113 2057  2369  Sunny   21      71  0
# 104 2013-07-21 4602 2134   2200 2122  2480  Sunny   21      68  0
# 105 2013-07-22 3841 1741   1881 1684  2157  Sunny   22      69 50
# 106 2013-07-23 3815 1713   1881 1678  2137  Sunny   22      64 40
# 107 2013-07-24 4031 1825   1994 1739  2292  Sunny   23      69 32

# %%
# Proof of concept
date[101:107]
# Out:
# [1] 2013-07-18 2013-07-19 2013-07-20 2013-07-21 2013-07-22 2013-07-23 2013-07-24
# 257 Levels: 2013-04-09 2013-04-10 2013-04-11 2013-04-12 ... 2013-12-21

# %%
write.csv(date, "../data/date.csv")

# %%
date
# Out:
#   [1] 2013-04-09 2013-04-10 2013-04-11 2013-04-12 2013-04-13 2013-04-14
#   [7] 2013-04-15 2013-04-16 2013-04-17 2013-04-18 2013-04-19 2013-04-20
#  [13] 2013-04-21 2013-04-22 2013-04-23 2013-04-24 2013-04-25 2013-04-26
#  [19] 2013-04-27 2013-04-28 2013-04-29 2013-04-30 2013-05-01 2013-05-02
#  [25] 2013-05-03 2013-05-04 2013-05-05 2013-05-06 2013-05-07 2013-05-08
#  [31] 2013-05-09 2013-05-10 2013-05-11 2013-05-12 2013-05-13 2013-05-14
#  [37] 2013-05-15 2013-05-16 2013-05-17 2013-05-18 2013-05-19 2013-05-20
#  [43] 2013-05-21 2013-05-22 2013-05-23 2013-05-24 2013-05-25 2013-05-26
#  [49] 2013-05-27 2013-05-28 2013-05-29 2013-05-30 2013-05-31 2013-06-01
#  [55] 2013-06-02 2013-06-03 2013-06-04 2013-06-05 2013-06-06 2013-06-07
#  [61] 2013-06-08 2013-06-09 2013-06-10 2013-06-11 2013-06-12 2013-06-13
#  [67] 2013-06-14 2013-06-15 2013-06-16 2013-06-17 2013-06-18 2013-06-19
#  [73] 2013-06-20 2013-06-21 2013-06-22 2013-06-23 2013-06-24 2013-06-25
# ...

# %%
# get index of specific date
initial = which(date == '2013-05-14')
final = initial + 6
initial
final
# Out:
# [1] 36
# [1] 42
