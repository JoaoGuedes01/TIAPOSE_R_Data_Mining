# %%
dates = read.csv(file = 'date.csv')["x"]

# %%
week = c(100:107)

# %%
dates[week,]
# Out:
# [1] 2013-07-17 2013-07-18 2013-07-19 2013-07-20 2013-07-21 2013-07-22 2013-07-23
# [8] 2013-07-24
# 257 Levels: 2013-04-09 2013-04-10 2013-04-11 2013-04-12 ... 2013-12-21

# %%
dates[107,]
# Out:
# [1] 2013-07-24
# 257 Levels: 2013-04-09 2013-04-10 2013-04-11 2013-04-12 ... 2013-12-21

# %%
cona = list(v1="cona1",v2="cona2")

# %%
cona[[elem]]
# Out:
# [1] "cona1"

# %%
elem = "v1"

# %%
cona = "cona"

# %%
cona
# Out:
# [1] "cona"

# %%
a = paste("Tu tens uma",cona)

# %%
a
# Out:
# [1] "Tu tens uma cona"
